# %%
import pygame
import random

# Initialize pygame
pygame.init()

# Define the window size
SCREEN_WIDTH = 800
SCREEN_HEIGHT = 600

# Define the player size and movement speed
PLAYER_WIDTH = 32
PLAYER_HEIGHT = 64
PLAYER_SPEED = 5

# Define the enemy size and movement speed
ENEMY_WIDTH = 32
ENEMY_HEIGHT = 32
ENEMY_SPEED = 3

# Define the bullet size and speed
BULLET_WIDTH = 8
BULLET_HEIGHT = 16
BULLET_SPEED = 10

# Define the colors
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLUE = (0, 0, 255)

# Load the font
font = pygame.font.SysFont(None, 24)

# Load the images
player_img = pygame.image.load('player.jpg')
enemy_img = pygame.image.load('enemy.jpg')
bullet_img = pygame.image.load('bullet.jpeg')

# Set the window title and icon
pygame.display.set_caption("Platformer Game")
icon_img = pygame.image.load('icon.jpeg')
pygame.display.set_icon(icon_img)

# Create the screen
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))

# Define a function to create a player object
def create_player():
    return {
        'rect': pygame.Rect((SCREEN_WIDTH - PLAYER_WIDTH) // 2, SCREEN_HEIGHT - PLAYER_HEIGHT - 20, PLAYER_WIDTH, PLAYER_HEIGHT),
        'x_speed': 0,
        'y_speed': 0,
        'jumping': False,
        'shooting': False,
        'bullets': []
    }

# Define a function to create an enemy object
def create_enemy():
    return {
        'rect': pygame.Rect(random.randint(0, SCREEN_WIDTH - ENEMY_WIDTH), -ENEMY_HEIGHT, ENEMY_WIDTH, ENEMY_HEIGHT),
        'y_speed': ENEMY_SPEED
    }

# Define a function to create a bullet object
def create_bullet(player_rect):
    return {
        'rect': pygame.Rect(player_rect.centerx - BULLET_WIDTH // 2, player_rect.top - BULLET_HEIGHT, BULLET_WIDTH, BULLET_HEIGHT),
        'y_speed': -BULLET_SPEED
    }

# Define a function to handle user input
def handle_input(player):
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            return False
        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_LEFT:
                player['x_speed'] = -PLAYER_SPEED
            elif event.key == pygame.K_RIGHT:
                player['x_speed'] = PLAYER_SPEED
            elif event.key == pygame.K_SPACE and not player['jumping']:
                player['y_speed'] = -10
                player['jumping'] = True
            elif event.key == pygame.K_z and not player['shooting']:
                player['bullets'].append(create_bullet(player['rect']))
                player['shooting'] = True
        elif event.type == pygame.KEYUP:
            if event.key == pygame.K_LEFT and player['x_speed'] < 0:
                player['x_speed'] = 0
            elif event.key == pygame.K_RIGHT and player['x_speed'] > 0:
                player
# Out:
# pygame 2.3.0 (SDL 2.24.2, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
